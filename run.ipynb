# %%
# !git clone https://github.com/mhmmd-hsn/decoding-lilingual-EEG-signals.git
# Out:
# Cloning into 'decoding-lilingual-EEG-signals'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 95 (delta 20), reused 21 (delta 11), pack-reused 58 (from 1)
# Receiving objects: 100% (95/95), 93.85 MiB | 23.61 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# !cd /content/decoding-lilingual-EEG-signals
# !unzip "/content/drive/MyDrive/Processed_Data_.zip" -d "/content/decoding-lilingual-EEG-signals"
# !pip install mne
# Out:
# Archive:  /content/drive/MyDrive/Processed_Data_.zip
#    creating: /content/decoding-lilingual-EEG-signals/Processed_Data_/
#    creating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-16-1/
#   inflating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-16-1/data_EEG_with_events.parquet
#    creating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-16-2/
#   inflating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-16-2/data_EEG_with_events.parquet
#    creating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-19-1/
#   inflating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-19-1/data_EEG_with_events.parquet
#    creating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-19-2/
#   inflating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-19-2/data_EEG_with_events.parquet
#    creating: /content/decoding-lilingual-EEG-signals/Processed_Data_/7-19-3/
# ...

# %%
# !python /content/decoding-lilingual-EEG-signals/main.py
# Out:
# Processing Sessions: 100% 56/56 [00:17<00:00,  3.26it/s]
# dataset shape: (504, 12, 2000), labels shape: (504,)
#
# 🔥 Total Trainable Parameters: 344,875
#
# 🔍 Layer-wise Parameter Breakdown:
# ...
# agacn1.weight                  252,000 parameters
# agacn1.bias                    126 parameters
# agacn2.weight                  8,064 parameters
# agacn2.bias                    64 parameters
# agacn3.weight                  8,448 parameters
# agacn3.bias                    132 parameters
# fc.weight                      76,032 parameters
# fc.bias                        9 parameters
# ...
#
# Fold 1/5
# Epoch 1, Train Loss: 223.5087, Train Acc: 0.1067, Val Loss: 250.2515, Val Acc: 0.1188
# Epoch 2, Train Loss: 179.6623, Train Acc: 0.1290, Val Loss: 181.4177, Val Acc: 0.0792
# Epoch 3, Train Loss: 128.8358, Train Acc: 0.1663, Val Loss: 176.7949, Val Acc: 0.1683
# Epoch 4, Train Loss: 151.1532, Train Acc: 0.1613, Val Loss: 136.3938, Val Acc: 0.0792
# ...
